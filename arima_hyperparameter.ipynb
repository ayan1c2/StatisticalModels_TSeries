# %%
# grid search ARIMA parameters for time series
import warnings
from math import sqrt
from pandas import read_csv
from pandas import datetime
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
import pandas as pd
import math

# %%
warnings.filterwarnings("ignore")

# %%
# evaluate an ARIMA model for a given order (p,d,q)
def evaluate_arima_model(X, arima_order):
	# prepare training dataset
	train_size = int(len(X) * 0.8)
	train, test = X[0:train_size], X[train_size:]
	history = [x for x in train]
	# make predictions
	predictions = list()
	for t in range(len(test)):
		model = ARIMA(history, order=arima_order)
		model_fit = model.fit()
		yhat = model_fit.forecast()[0]
		predictions.append(yhat)
		history.append(test[t])
	# calculate out of sample error
	rmse = sqrt(mean_squared_error(test, predictions))
	return rmse

# %%
# evaluate combinations of p, d and q values for an ARIMA model
def evaluate_models(dataset, p_values, d_values, q_values):
	dataset = dataset.astype('float32')
	best_score, best_cfg = float("inf"), None
	for p in p_values:
		for d in d_values:
			for q in q_values:
				order = (p,d,q)
				try:
					rmse = evaluate_arima_model(dataset, order)
					if rmse < best_score:
						best_score, best_cfg = rmse, order
					print('ARIMA%s RMSE=%.3f' % (order,rmse))
				except:
					continue
	print('Best ARIMA%s RMSE=%.3f' % (best_cfg, best_score))

# %%
# load dataset
def parser(x):
	return datetime.strptime('190'+x, '%Y-%m')

# %%
#series = read_csv('./Input/shampoo.csv', header=0, index_col=0, parse_dates=True, squeeze=True, date_parser=parser)
series = pd.read_csv('p16_steps.csv', header=0, parse_dates=[0], index_col=0, squeeze=True)

# %%
# evaluate parameters
p_values = [1, 2, 4, 6, 8, 10]
d_values = range(0, 5)
q_values = range(0, 5)

evaluate_models(series.values, p_values, d_values, q_values)
# Out:
# ARIMA(1, 0, 0) RMSE=861.664
# ARIMA(1, 0, 1) RMSE=874.366
# ARIMA(1, 0, 2) RMSE=875.129
# ARIMA(1, 0, 3) RMSE=784.718
# ARIMA(1, 0, 4) RMSE=785.234
# ARIMA(1, 1, 0) RMSE=876.574
# ARIMA(1, 1, 1) RMSE=703.625
# ARIMA(1, 1, 2) RMSE=719.797
# ARIMA(1, 1, 3) RMSE=727.419
# ARIMA(1, 1, 4) RMSE=720.386
# ARIMA(1, 2, 0) RMSE=1334.558
# ARIMA(1, 2, 1) RMSE=881.364
# ARIMA(1, 2, 2) RMSE=707.985
# ARIMA(1, 2, 3) RMSE=707.105
# ARIMA(1, 2, 4) RMSE=728.240
# ARIMA(1, 3, 0) RMSE=2192.763
# ARIMA(1, 3, 1) RMSE=1338.392
# ARIMA(1, 3, 2) RMSE=893.609
# ARIMA(1, 3, 3) RMSE=855.230
# ARIMA(1, 3, 4) RMSE=746.721
# ARIMA(1, 4, 0) RMSE=3759.692
# ARIMA(1, 4, 1) RMSE=2198.449
# ARIMA(1, 4, 2) RMSE=1349.358
# ARIMA(1, 4, 3) RMSE=1056.348
# ARIMA(1, 4, 4) RMSE=1107.891
# ARIMA(2, 0, 0) RMSE=874.123
# ARIMA(2, 0, 1) RMSE=875.131
# ARIMA(2, 0, 2) RMSE=824.405
# ARIMA(2, 0, 3) RMSE=760.590
# ARIMA(2, 1, 0) RMSE=837.999
# ARIMA(2, 1, 1) RMSE=703.877
# ARIMA(2, 1, 2) RMSE=717.300
# ARIMA(2, 1, 3) RMSE=739.517
# ARIMA(2, 1, 4) RMSE=735.297
# ARIMA(2, 2, 0) RMSE=1166.646
# ARIMA(2, 2, 1) RMSE=842.964
# ARIMA(2, 2, 2) RMSE=692.300
# ARIMA(2, 2, 3) RMSE=738.559
# ARIMA(2, 2, 4) RMSE=778.453
# ARIMA(2, 3, 0) RMSE=1769.197
# ARIMA(2, 3, 1) RMSE=1169.236
# ARIMA(2, 3, 2) RMSE=842.077
# ARIMA(2, 4, 0) RMSE=2846.145
# ARIMA(2, 4, 1) RMSE=1772.143
# ARIMA(2, 4, 2) RMSE=146887026.962
# ARIMA(4, 0, 0) RMSE=858.074
# ARIMA(4, 0, 1) RMSE=857.972
# ARIMA(4, 0, 2) RMSE=750.172
# ARIMA(4, 0, 3) RMSE=782.003
# ARIMA(4, 0, 4) RMSE=903.066
# ARIMA(4, 1, 0) RMSE=793.361
# ARIMA(4, 1, 1) RMSE=709.319
# ARIMA(4, 1, 2) RMSE=731.557
# ARIMA(4, 1, 3) RMSE=718.357
# ARIMA(4, 1, 4) RMSE=728.557
# ARIMA(4, 2, 0) RMSE=1021.585
# ARIMA(4, 2, 1) RMSE=798.300
# ARIMA(4, 2, 2) RMSE=25866.493
# ARIMA(4, 2, 3) RMSE=902.068
# ARIMA(4, 2, 4) RMSE=723.243
# ARIMA(4, 3, 0) RMSE=1343.663
# ARIMA(4, 3, 1) RMSE=1024.028
# ARIMA(4, 3, 3) RMSE=824.929
# ARIMA(4, 3, 4) RMSE=883.485
# ARIMA(4, 4, 0) RMSE=1959.539
# ARIMA(4, 4, 1) RMSE=1348.507
# ARIMA(4, 4, 3) RMSE=1073.366
# ARIMA(6, 0, 0) RMSE=800.069
# ARIMA(6, 0, 1) RMSE=763.142
# ARIMA(6, 0, 2) RMSE=866.127
# ARIMA(6, 0, 3) RMSE=831.899
# ARIMA(6, 0, 4) RMSE=851.525
# ARIMA(6, 1, 0) RMSE=706.336
# ARIMA(6, 1, 1) RMSE=710.955
# ARIMA(6, 1, 2) RMSE=703.254
# ARIMA(6, 1, 3) RMSE=730.605
# ARIMA(6, 1, 4) RMSE=787.074
# ARIMA(6, 2, 0) RMSE=937.803
# ARIMA(6, 2, 1) RMSE=711.904
# ARIMA(6, 2, 2) RMSE=763.241
# ARIMA(6, 2, 3) RMSE=721.359
# ARIMA(6, 2, 4) RMSE=772.151
# ARIMA(6, 3, 0) RMSE=1289.581
# ARIMA(6, 3, 1) RMSE=939.074
# ARIMA(6, 3, 2) RMSE=1471913.955
# ARIMA(6, 3, 3) RMSE=759.354
# ARIMA(6, 3, 4) RMSE=837.702
# ARIMA(6, 4, 0) RMSE=1918.264
# ARIMA(6, 4, 1) RMSE=1322.959
# ARIMA(6, 4, 2) RMSE=1047.501
# ARIMA(6, 4, 4) RMSE=886.568
# ARIMA(8, 0, 0) RMSE=763.533
# ARIMA(8, 0, 1) RMSE=762.675
# ARIMA(8, 0, 2) RMSE=775.014
# ARIMA(8, 0, 3) RMSE=799.501
# ARIMA(8, 0, 4) RMSE=871.882
# ARIMA(8, 1, 0) RMSE=733.939
# ARIMA(8, 1, 1) RMSE=695.025
# ARIMA(8, 1, 3) RMSE=740.670
# ARIMA(8, 1, 4) RMSE=754.089
# ARIMA(8, 2, 0) RMSE=1014.474
# ARIMA(8, 2, 1) RMSE=733.518
# ARIMA(8, 2, 2) RMSE=787.367
# ARIMA(8, 2, 3) RMSE=790.962
# ARIMA(8, 2, 4) RMSE=786.782
# ARIMA(8, 3, 0) RMSE=1349.913
# ARIMA(8, 3, 1) RMSE=1003.652
# ARIMA(8, 3, 2) RMSE=744.876
# ARIMA(8, 3, 3) RMSE=813.373
# ARIMA(8, 4, 0) RMSE=1724.351
# ARIMA(8, 4, 1) RMSE=4700422736624565.000
# ARIMA(8, 4, 3) RMSE=975.804
# ARIMA(8, 4, 4) RMSE=1013.482
# ARIMA(10, 0, 0) RMSE=833.808
# ARIMA(10, 0, 1) RMSE=829.363
# ARIMA(10, 0, 2) RMSE=938.305
# ARIMA(10, 0, 3) RMSE=943.820
# ARIMA(10, 0, 4) RMSE=981.921
# ARIMA(10, 1, 0) RMSE=782.416
# ARIMA(10, 1, 1) RMSE=778.623
# ARIMA(10, 1, 2) RMSE=712.709
# ARIMA(10, 1, 3) RMSE=823.773
# ARIMA(10, 1, 4) RMSE=750.681
# ARIMA(10, 2, 0) RMSE=893.003
# ARIMA(10, 2, 1) RMSE=787.288
# ARIMA(10, 2, 2) RMSE=786.570
# ARIMA(10, 2, 3) RMSE=780.190
# ARIMA(10, 2, 4) RMSE=888.410
# ARIMA(10, 3, 0) RMSE=1137.737
# ARIMA(10, 3, 1) RMSE=908.301
# ARIMA(10, 3, 2) RMSE=812.631
# ARIMA(10, 3, 3) RMSE=815.205
# ARIMA(10, 3, 4) RMSE=864.130
# ARIMA(10, 4, 0) RMSE=1463.245
# ARIMA(10, 4, 1) RMSE=1129.064
# ARIMA(10, 4, 2) RMSE=930.771
# ARIMA(10, 4, 3) RMSE=926.761
# ARIMA(10, 4, 4) RMSE=1021.428
# Best ARIMA(2, 2, 2) RMSE=692.300
